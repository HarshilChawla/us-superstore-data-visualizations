# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv(r'C:\DATA ANALYSIS AND DATA SCIENCE PROJECTS\US Superstore Data Visualizations\data\us_superstore_dataset.csv')

# %% [markdown]
# # SCATTER PLOT
# *Used to show relationship between two numeric variables*

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%d-%m-%Y', errors='coerce')
data['Ship Date'] = pd.to_datetime(data['Ship Date'], format='%d-%m-%Y', errors='coerce')
data['Shipment Delay (Days)'] = (data['Ship Date'] - data['Order Date']).dt.days

# %%
#Shipment Delay vs Quantity
plt.figure(figsize = (8, 6))
plt.scatter(data['Quantity'], data['Shipment Delay (Days)'])
plt.xlabel('Quantity', fontsize=12, color='darkblue')
plt.ylabel('Shipment Delay (Days)', fontsize=12, color='darkblue')
plt.title('Shipment Delay vs Quantity', fontsize=14, fontweight='bold')
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()  
plt.legend()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7844\552440492.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
data[['Quantity', 'Shipment Delay (Days)']].corr()
# Out:
#                        Quantity  Shipment Delay (Days)
# Quantity               1.000000               0.018298
# Shipment Delay (Days)  0.018298               1.000000

# %% [markdown]
# * **Observation:** There is no visible relationship between shipment delay and quantity.
#
# * **Insight:** The delay in shipment appears to be independent of order size, indicating that shipping processes are likely standardized across different order volumes.

# %%
#Sales vs Profit
plt.figure(figsize = (8, 6))
plt.scatter(data['Sales'], data['Profit'], 
            c= 'purple', 
            edgecolor= 'black', 
            linewidth= 0.6)
plt.xlabel('Sales', fontsize = 12)
plt.ylabel('Profit', fontsize = 12)
plt.title('Sales vs Profit', fontsize = 14, fontweight = 'bold')
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()  
plt.legend()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_30520\2461449945.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Sales vs Discount
plt.figure(figsize = (8, 6))
plt.scatter(data['Sales'], data['Discount'], 
            c= 'teal', 
            edgecolor= 'black', 
            linewidth= 0.6)
plt.xlabel('Sales', fontsize = 12)
plt.ylabel('Discount', fontsize = 12)
plt.title('Sales vs Discount', fontsize = 14, fontweight = 'bold')
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.tight_layout()  
plt.legend()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_30520\2502282693.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
